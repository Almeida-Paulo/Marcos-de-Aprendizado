# %%
import numpy as np
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['year'] = df['date'].dt.year

# %%
px.histogram(df, x='date', nbins=13)
#fig.show()
# Out:
# <div>                            <div id="6b1ce294-92d6-4a89-b11b-002edae7b58b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b1ce294-92d6-4a89-b11b-002edae7b58b")) {                    Plotly.newPlot(                        "6b1ce294-92d6-4a89-b11b-002edae7b58b",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"date=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":13,"offsetgroup":"","orientation":"v","showlegend":false,"x":["2014-10-13T00:00:00","2014-12-09T00:00:00","2015-02-25T00:00:00","2014-12-09T00:00:00","2015-02-18T00:00:00","2014-05-12T00:00:00","2014-06-27T00:00:00","2015-01-15T00:00:00","2015-04-15T00:00:00","2015-03-12T00:00:00",
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df['yr_renovated'].unique()
# Out:
# array([   0, 1991, 2002, 2010, 1999, 1992, 2013, 1994, 1978, 2005, 2008,
#        2003, 1984, 1954, 2014, 2011, 1974, 1983, 1945, 1990, 1988, 1957,
#        1977, 1981, 1995, 2000, 1998, 1970, 1989, 2004, 1986, 2009, 2007,
#        1987, 1973, 2006, 1985, 2001, 1980, 1971, 1979, 1997, 1950, 1969,
#        1948, 2015, 1968, 2012, 1963, 1951, 1993, 1962, 1996, 1972, 1953,
#        1955, 1982, 1956, 1940, 1976, 1946, 1975, 1958, 1964, 1959, 1960,
#        1967, 1965, 1934, 1944], dtype=int64)

# %% [markdown]
# # fazendo o dataset para o dashboard_casas.pbix

# %%
df_meanZIP = df[['price', 'zipcode']].groupby('zipcode').mean().reset_index()

# %%
df['price_m^2'] = df['price'] / df['sqft_lot']

# %%
df_meanM2 = df[['price_m^2', 'zipcode']].groupby('zipcode').mean().reset_index()

# %%
data = pd.merge(m2, df4, on='zipcode', how='inner') #juntar dataframes a partir de uma coluna

# %%
df = df.round(2) #dataframe
media_total = round((nota_CN + nota_CH + nota_LC + nota_MT + nota_REDACAO)/5, 2) #numero isolado

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)
df_meanZIPNotation = df_meanZIP

# %%
data = pd.merge(df_meanZIPNotation, df_meanM2, on='zipcode', how='inner')

# %%
dataINT = data.round(0)

# %%
dataINT.to_csv('kc_house_data_zipmeans_certo.csv', index=False)

# %%
dataINT['price'] = dataINT['price'].astype(int)
dataINT['price_m^2'] = dataINT['price_m^2'].astype(int)

# %%
dataINT
# Out:
#     zipcode    price  price_m^2
# 0     98001   280805         31
# 1     98002   234284         37
# 2     98003   294111         33
# 3     98004  1355927        123
# 4     98005   810165         61
# ..      ...      ...        ...
# 65    98177   676185         71
# 66    98178   310613         43
# 67    98188   289078         31
# 68    98198   302879         36
# 69    98199   791821        173
#
# [70 rows x 3 columns]
